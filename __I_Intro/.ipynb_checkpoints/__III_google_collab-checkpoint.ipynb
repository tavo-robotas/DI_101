# %% [markdown]
# # Google Colab

# %% [markdown]
# Puikūs skaičiavimo ištekliai debesyse, kuriuos galima nemokamai naudoti neuroninių tinklų mokymo procesams. Peržiūrėkite šį įrankių sąrašą: https://github.com/zszazi/Deep-learning-in-cloud, skirtą skaičiavimų operacijoms ir daugumai palaikančių GPU, <code>**bet ne visi yra nemokami**</code>. Šio kuros reikmėms mes naudosime google colab: https://colab.research.google.com/

# %% [markdown]
# ## Temos

# %% [markdown]
# <code>**1: GPU resursai**</code><br>
# <code>**2: Google Collab aplinka**</code><br>
# <code>**3: CUDA nustatymai**</code><br>
# <code>**4: Github saugykla tiesiogiai colab aplinkoje**</code><br>
# <code>**5: Gdrive sąsaja**</code><br>

# %% [markdown]
#  ## Colab aplinka

# %% [markdown]
# Tai kaip jupyter aplinka. Ją lengva naudoti ir peržiūrėti rezultatus, tačiau kai kodas tampa sudėtingesnis, ilgesnis kartais labao patogu naudoti aplinką nuotoliniame serveryje kuris palaiko python programvimo kalbą. Taigi rekomenduoju išnagrinėti tą minetą sąrašą, ir rasti tai, kas jums bus tinkama naudoti vėliau. Galų gale tai priklauso nuo jūsų, ką norite daryti savo švietimo veiklai / projektams. Tačiau <code>**Google Colab**</code> yra  tinkamas pradedantiesiems nes:
#  - Nieko nereikia konfigūruoti
#  - Galimybė pasiekti nemokamus grafikos procesorius
#  - Paprasta bendrinti

# %% [markdown]
# ![google_collab_env.jpg](attachment:google_collab_env.jpg)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('inN8seMm7UI', width=1500, height=800)

# %% [markdown]
# ### Vykdymo aplinka

# %% [markdown]
# 1) Eikite į vykdymo aplinką

# %% [markdown]
# ![colab_environment_section.jpg](attachment:colab_environment_section.jpg)

# %% [markdown]
# 2) Pasirinkite GPU aplinką

# %% [markdown]
# ![colab_gpu_select_a.jpg](attachment:colab_gpu_select_a.jpg)

# %% [markdown]
# ![colab_gpu_select_b.jpg](attachment:colab_gpu_select_b.jpg)

# %% [markdown]
# 3) Patikrinkite ar PyTorch biblioteka ir cuda (GPU branduoliai) yra pasiekiami

# %% [markdown]
# ![colab_torch_cuda.jpg](attachment:colab_torch_cuda.jpg)

# %% [markdown]
# colab turi pytoch versija 1.12.1+cu113, t.y 1.12.1 kuri yra naujausia. Taip pat šis cu113 yra google specifinis dalykas. Kadangi paprastai tai nerodoma, kai į savo kompiuterį importuojame pytorch. Tai reiškia, kad ši PyTorch versija palaiko cuda 11.3

# %% [markdown]
# 4) Eikite į Failas > Atidaryti užrašinę

# %% [markdown]
# ![colab_open_notebook.jpg](attachment:colab_open_notebook.jpg)

# %% [markdown]
# 5)Pasirinkite Github skirtuką ir nukopijuokite ir įklijuokite konkretų .ipynb žunralo failą arba visą saugyklą su užrašinės failais ir pasirinkite iš sąrašo tą kurį norite įkelti

# %% [markdown]
# ![colab_open_github_repo.jpg](attachment:colab_open_github_repo.jpg)

# %% [markdown]
# Tarkime išsirinkote iš sąrašo google_collab_example.ipynb tačiau bandydami vykdyti kodą šiame žurnale pamatysite šį įspėjamąjį pranešimą.

# %% [markdown]
# ![colab_warning.jpg](attachment:colab_warning.jpg)

# %% [markdown]
# Išsaugokite atidarytą žurnalaą, „colab“ aplinka parodys tokią klaidą:

# %% [markdown]
# ![colab_saving_error.jpg](attachment:colab_saving_error.jpg)

# %% [markdown]
# Turime padaryti kopiją, nes ji įkeliama tiesiai iš github saugyklos ir neleidžia mums perrašyti failo šioje konkrečioje saugykloje, o tai yra gerai. Tiesiog išsaugokite jį vietiniame savo Google vietiniame diske.

# %% [markdown]
# Jei mėgintume įkelti kokį nors tarkime failą su duomenimis .csv .txt ir pan. formatu, gautime pranešimą kad yra `FileNotFoundError` klaidą. Reikalas tas, kad mes įkėlėme žurnalą, bet neįkėlėme duomenų. Jei pažiūrėtume į mūsų kurso duomenų rinkinių šakninę saugyklą poaplankyje <code>**data_samples**</code>, mes turime duomenų rinkinį iris.data, apie kurį šis colab žurnalas google collab aplinkoje nieko nežino, iš kur įkelti duomenis. Vienas iš būdų yra nukopijuoti csv katalogo nuorodą ir pateikti pd.read_csv metodą, jį galima įkelti tiesiai iš csv failo, saugomo nuotoliniame serveryje. Tačiau praktiškai, jei turime duomenų failą, kuris nėra csv failas, ir jis yra jūsų kompiuteryje. Mes norime turėti bendresnį sprendimą. Tam turėsime prijungti „Google“ disko aplanką. Taigi tai yra šiek tiek sudėtinga. Taigi tarkime, kad šį duomenų rinkinį iris.data turime vietoje , o jei to neturite, atsisiųskite jį. Eikite į „Google“ diską ir pastebėsite, kad yra „Colab“ užrašų knygelių aplankas. Tai sugeneruojama automatiškai jūsų paskyroje.
